# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание по статистическому анализу на python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline
import statistics

# %% [markdown]
# Загрузить датасет по url:

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
df=pd.read_csv(url)

# %% [markdown]
# Более подробно о датасете можно прочитать по [данной ссылке](https://data.world/promptcloud/world-happiness-report-2019) или по [ссылке в kaggle](https://www.kaggle.com/PromptCloudHQ/world-happiness-report-2019)

# %% [markdown]
# Контекст
#
# Доклад о мировом счастье - это знаковое исследование состояния глобального счастья, в котором 156 стран ранжируются по тому, насколько счастливыми считают себя их граждане. Доклад о мировом счастье за этот год посвящен счастью и сообществу: как счастье эволюционировало за последние десять лет, с акцентом на технологии, социальные нормы, конфликты и государственную политику, которые привели к этим изменениям.

# %% [markdown]
# 1 **Country (region)** Страна (регион) Название страны.
#
# 2 **Ladder** Лестница Кантрил - это показатель удовлетворенности жизнью.
#
# 3 **SD of Ladder** SD стандартного отклонения лестницы.
#
# 4 **Positive affect** Положительный аффект - мера положительной эмоции.
#
# 5 **Negative affect** Негативный аффект - мера негативной эмоции.
#
# 6 **Social support** Социальная поддержка - степень, в которой социальная поддержка повлияла на расчет показателя счастья.
#
# 7 **Freedom** Свобода - степень, в которой свобода повлияла на расчет показателя счастья.
#
# 8 **Corruption** Коррупция - степень, в которой восприятие коррупции влияет на показатель счастья.
#
# 9 **Generosity** Щедрость - степень, в которой щедрость способствовала расчету показателя счастья.
#
# 10 **Log of GDP per capita** Логарифм ВВП на душу населения Показывает, в какой степени ВВП вносит вклад в расчет показателя счастья.
#
# 11 **Healthy life expectancy** Ожидаемая продолжительность здоровой жизни - степень, в которой ожидаемая продолжительность жизни повлияла на расчет показателя счастья.

# %% [markdown]
# Посмотреть первые несколько рядов таблицы

# %%
df = df.loc[df['Country (region)']!='Qatar', :] #Удалили страну Катар так как там были значения non

# %%
df.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
len(df)
# Out:
# 155

# %% [markdown]
# Построить частотный график для двух параметров: Freedom и positive affect. Какое это распределение?

# %%
Freedom = df['Freedom']
Positive_affect = df['Positive affect']
fig, ax = plt.subplots()
ax.scatter(Freedom, Positive_affect, c='red', alpha=0.3, edgecolors='none')

ax.grid(True)
plt.xlabel('Свобода')
plt.ylabel('Положительный аффект')
plt.show()

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(df['Freedom'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('avg_vote')
plt.title('Частотный график Freedom (разбиение интервала по 50 элементов)')
plt.grid(True)
plt.show()

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(df['Positive affect'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('avg_vote')
plt.title('Частотный график Positive affect (разбиение интервала по 50 элементов)')
plt.grid(True)
plt.show()

# %% [markdown]
# Найти медиану, моду, математическое ожидание, стандартное отклонение,  дисперсию, минимум и максимум, найти выбросы (если есть), размах для колонки Freedom

# %% [markdown]
# # Математические ожидание и среднее значение

# %%
freedom = df['Freedom']

# %%
statistics.mean(df['Freedom'])
# Out:
# 78.0

# %%
sum(df['Freedom'])/len(df['Freedom'])
# Out:
# 78.0

# %% [markdown]
# # Мода

# %%
statistics.mode(df['Freedom'])
# Out:
# 5.0

# %%
# Создаём пустой словарь, в котором будем считать количество появлений значений продолжительности фильма
freedom_counts = {}
for p in freedom:
    if p not in freedom_counts:
        freedom_counts[p] = 1
    else:
        freedom_freedom[p] += 1

# Проходимся по словарю и ищем максимальное количество повторений
# Алгоритм поиска максимума
maxp = 0
mode_freedom = None
for k, v in freedom_counts.items():
    if maxp < v:
        maxp = v
        mode_freedom = k
print('Значение моды: ', mode_freedom, 'Количество встречаемости: ', maxp)
# Out:
# Значение моды:  5.0 Количество встречаемости:  1

# %% [markdown]
# # Медиана

# %%
statistics.median(freedom)
# Out:
# 78.0

# %%
print ('MAX:', max(freedom), ',', 'MIN:', min(freedom))
# Out:
# MAX: 155.0 , MIN: 1.0

# %% [markdown]
# # Выбросы

# %%
freedom.isnull().sum()
# Out:
# 0

# %%
duration.isnull().sum()

# %% [markdown]
# # Стандартное отклонение

# %%
statistics.pstdev(freedom)
# Out:
# 44.74371464239419

# %%
def stdev(nums):
    diffs = 0
    avg = sum(nums)/len(nums)
    for n in nums:
        diffs += (n - avg)**(2)
    return (diffs/(len(nums)-1))**(0.5)

print(stdev(freedom))
# Out:
# 2015.0000000000002

# %% [markdown]
# # Дисперсия

# %%
statistics.pvariance(freedom)
# Out:
# 2002.0

# %% [markdown]
# # Размах

# %%
freedom_range = max(freedom) - min(freedom)
print(freedom_range)
# Out:
# 154.0

# %% [markdown]
# Почему нельзя найти моду?

# %%
Потому что все значения уникальны

# %% [markdown]
# Посмотреть корреляцию между Freedom и positive affect (графически и математически). Графически - plt.scatter, математически - посчитать коэффициент Пирсона. О чем говорит знак коэффициента?

# %%
Freedom = df['Freedom']
Positive_affect = df['Positive affect']
plt.xlabel('выборка Freedom')
plt.ylabel('выборка Positive affect')
plt.title('Точечный график зависимости двух выборок Свобода и Позитивный эффект')
plt.grid(True)
plt.scatter(Freedom, Positive_affect, marker='.')

# %%
from scipy.stats import pearsonr
positive_affect = df['Positive affect'] 

corr, p_value = pearsonr(freedom, positive_affect)
print(corr)
# Out:
# 0.6817698430601657

# %%
from scipy.stats import pearsonr


corr, p_value = pearsonr(freedom, positive_affect)
plt.scatter(freedom, positive_affect, marker='.')
print('Коэффициент корреляции Пирсона:', corr)
# Out:
# Коэффициент корреляции Пирсона: 0.6817698430601657

# %% [markdown]
# # Нормализация данных колонки Freedom (централизация + масштабирование)

# %% [markdown]
# ### Центрирование

# %%
freedom_1 = freedom - statistics.mean(freedom)
print(statistics.mean(freedom_1))
# Out:
# 0.0

# %% [markdown]
# ### Масштабирование
# Разброс данных приводим к виду (0,1) либо (-1,1)

# %%
min(freedom_1)
# Out:
# -77.0

# %%
max(freedom_1)
# Out:
# 77.0

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))

freedom_2 = min_max_scaler.fit_transform(np.array(freedom_1).reshape(-1, 1))
print(min(freedom_2))
print(max(freedom_2))
# Out:
# [-1.]
# [1.]

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(freedom_2, 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('avg_vote')
plt.title('Частотный график Freedom (разбиение интервала по 50 элементов)')
plt.grid(True)
plt.show()

# %% [markdown]
# Построить матрицу корреляций для всех колонок таблицы

# %%
import io
import requests

import seaborn as sns
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(8,8)
plt.show()

# %% [markdown]
# В данном датасете некоторые атрибуты значительно коррелируют. Какие? Почему?

# %% [markdown]
# Загрузить таблицу цен на авокадо:

# %%
import io
import requests
url="http://yustiks.ru/avocado.csv"
df=pd.read_csv(url)
df[:3]
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany

# %% [markdown]
# Сделать частотный график колонки AveragePrice. Какое это распределение?

# %% [markdown]
# Найти корреляцию в следующих колонках:

# %% [markdown]
# колонкой 4046, 4225, 4770 и Average Price. Если корелляция есть (обратная или прямая), то какие выводы можно сделать?

# %% [markdown]
# Написать временные предсказания цен на авокадо типа organic для выбранного региона: LasVegas, начиная с августа 2017 года до конца марта 2018. В качестве тренировочных данных использовать данные до июля 2017 года включительно.
# В качестве примера использовать лекционный материал в lecture_1.ipynb
